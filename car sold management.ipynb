# %%
import random as rd
# used car program
print("-----------WELCOME TO THE SECONDS CAR UNIVERSE------------")
x=True
while x:
    print()
    name=input("NAME:").upper()
    loc=input("CURRENT_LOCATION:").upper()
    email=input("EMAIL:")
    if '@gmail.com' in email:
        mob=input("MOBILE_NUMBER:")
        if len(mob)==10:
            print()
            print("---------------REGISTRATION COMPLETED--------------")
            x=False
        else:
            print()
            print("------------INVALID MOBILE NUMBER-------------------")
            x=True
    else:
        print()
        print("---------------INVALID EMAIL-ID--------------------------")
        x=True
class car:
    def sel_car(self):
        print("-------------------SELECT THE BRANDS OF YOUR CAR------------")
        print()
        self.pro=['MARUTHI SUZUKI','HYUNDAI','TATA','HONDA','RENAULT','VOLKSWAGEN','NISSAN','MAHINDRA','KIA','FORD','SKODA','BMW','TOYOTA','AUDI',
                 'MG MOTORS']
        c1=1
        for i1 in self.pro:
            print(c1,'.',i1)
            c1=c1+1
        app=True
        while app:
            self.list=input("SELECT YOUR CAR BRAND FROM THE ABOVE LIST").upper()
            if self.list in self.pro:
                if self.list=='MARUTHI SUZUKI':
                    print("CHOOSE YOUR RTO LOCATION:")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['BALENO','WAGON','SWIFT','BREZZA','EECO','ERTIGA']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','ABOVE 50K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="HYUNDAI":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['CRETA','VERNA','XCENT','VENUE','ALCAZAR','I20 N LINE','GRAND I10 NIOS']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','ABOVE 50K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="TATA":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['TIAGO','NEXON','ALTROZ','TIGOR','HARRIER','PUNCH','SAFARI','NEXON EV','TIGOR EV']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="HONDA":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['CITY','AMAZE','JAZZ','WR-V','MOBILO']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="RENAULT":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['KWID','TRIBER','DUSTER','KIGER']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="VOLKSWAGEN":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['POLO','VENTO','TAIGUN','VIRTUS','JETTA']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="NISSAN":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['MAGNITE','KICKS']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="MAHINDRA":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['XUV500','XUV300','THAR','KUV100','XUV700','SCORPIO','BOLERA NEO']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="KIA":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['SONET','SELTOS','CARENS','CARNIVAL']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            print(self.ownership,end="")
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="FORD":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['ECOSPORT','FIGO','FIGO ASPIRE','FREESTYLE','ENDEAVOUR']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="SKODA":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['KUSHAQ','RAPID NEW','OCTAVIA','SUPERB','KARAQ','KODIAQ']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="BMW":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['X1','3 SERIES','5 SERIES','X3','X4','X5','6 SERIES','7 SERIES']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="TOYOTA":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['GLANZA','INNOVA CRYSTA','CAMRY','URBAN CRUISER HYRYDER','FORTUNER','RUMION','INNOVA HYCROSS','HILUX']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="AUDI":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['Q3','A4','A6','Q5','Q2','Q7']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
                elif self.list=="MG MOTORS":
                    print("--------------CHOOSE YOUR RTO LOCATION----------")
                    print()
                    self.loc=["CHENNAI",'COIMBATORE','ERODE','MADURAI','DELHI','MUMBAI','PUNE','HYDERABAD','BANGALORE','KOLKATA','JAIPUR'
                             'JAMNAGAR','MYSORE','SALEM','SURAT','TRICHY','TIRUPPUR']
                    for i2 in self.loc:
                        print(i2)
                    self.location=input("SELECT LOCATION FROM THE ABOVE LIST:")
                    if self.location in self.loc:
                        print("--------CHOOSE MODEL OF YOUR CAR----------")
                        print()
                        self.model=['HECTOR','ASTOR','HECTOR PLUS','GLOSTER']
                        for i3 in self.model:
                            print(i3)
                        self.user_model=input("SELECT YOUR CAR MODEL FROM ABOVE LIST:")
                        if self.user_model in self.model:
                            self.year=input("ENTER CAR MANUFACTURING YEAR:")
                            if len(self.year)==4:
                                print("-----------CHOOSE FUEL TYPE OF YOUR CAR------------")
                                print()
                                self.vari=['PETROL','DIESEL','CNG']
                                for i4 in self.vari:
                                    print(i4)
                                self.user_vari=input("ENTER YOUR CAR FUEL TYPE")
                                if self.user_vari in self.vari:
                                    print("-------------CHOOSE TRANSMISSION OF YOUR CAR----------")
                                    print()
                                    self.trans=["MANUAL",'AUTOMATIC']
                                    for i5 in self.trans:
                                        print(i5)
                                    self.user_trans=input("ENTER YOUR CAR TRANSMISSION")
                                    if self.user_trans in self.trans:
                                        print("--------------CHOOSE KM DRIVEN BY YOUR CAR-----------")
                                        print()
                                        self.km=['0-10k','10k-20k','20k-30k','30k-40k','40k-50k','50K-60K','60K-70K','70K-80K','ABOVE 80K']
                                        for i6 in self.km:
                                            print(i6)
                                        self.user_km=input("SELECT KM DRIVEN BY YOUR CAR:")
                                        if self.user_km in self.km:
                                            print("--------------CHOOSE OWNERSHIP HISTORY OF YOUR CAR--------------")
                                            self.ownership=["1ST OWNER",'2ND OWNER','3RD OWNER','I AM THE CAR DEALER']
                                            for i7 in self.ownership:
                                                print(i7)
                                            self.user_ownership=input("SELECT OWNER SHIP OF YOUR CAR:")
                                            if self.user_ownership in self.ownership:
                                                self.otp=rd.randint(1000,9999)
                                                print("OTP IS SENT TO THE REGISTER MOBILE NUMBER",mob)
                                                print("YOUR OTP IS",self.otp)
                                                self.otps=int(input("ENTER OTP"))
                                                if self.otps==self.otp:
                                                    print("----CONGRATS YOU COMPLETED YOUR CAR SELLING PROCESS DEALER WILL CALL YOU SOON-----")
                                                    app=False
                                                else:
                                                    print("SORRY YOU ENTERED WRONG OTP")
                                                    self.ra=input("DO YO WANT TO CONTINUE THE PROCESS(YES/NO):")
                                                    if self.ra=='YES':
                                                        app=True
                                                    elif self.ra=='NO':
                                                        app=False
                                                    else:
                                                        print("INVALID OPTION")
                                                        app=True
            elif self.list not in self.pro:
                print("SORRY YOU HAVE CHOOSEN THE INVALID CAR!")
                self.exit=input("DO YOU WANT TO CONTINUE(YES/NO):").upper()
                if self.exit=='YES':
                    app=True
                elif self.exit=='NO':
                    app=False
                else:
                    print("INVALID OPTION")
                    app=True
cars=car()
cars.sel_car()
# Out:
# -----------WELCOME TO THE SECONDS CAR UNIVERSE------------
# NAME: RAGHUL
# CURRENT_LOCATION: CHENNAI
# EMAIL: raghulkumar3900@gmail.com
# MOBILE_NUMBER: 1234567890
# ---------------REGISTRATION COMPLETED--------------
# -------------------SELECT THE BRANDS OF YOUR CAR------------
#
# 1 . MARUTHI SUZUKI
# 2 . HYUNDAI
# 3 . TATA
# 4 . HONDA
# 5 . RENAULT
# 6 . VOLKSWAGEN
# 7 . NISSAN
# 8 . MAHINDRA
# 9 . KIA
# 10 . FORD
# 11 . SKODA
# 12 . BMW
# 13 . TOYOTA
# 14 . AUDI
# 15 . MG MOTORS
# SELECT YOUR CAR BRAND FROM THE ABOVE LIST RENAULT
# --------------CHOOSE YOUR RTO LOCATION----------
#
# CHENNAI
# COIMBATORE
# ERODE
# MADURAI
# DELHI
# MUMBAI
# PUNE
# HYDERABAD
# BANGALORE
# KOLKATA
# JAIPURJAMNAGAR
# MYSORE
# SALEM
# SURAT
# TRICHY
# TIRUPPUR
# SELECT LOCATION FROM THE ABOVE LIST: COIMBATORE
# --------CHOOSE MODEL OF YOUR CAR----------
#
# KWID
# TRIBER
# DUSTER
# KIGER
# SELECT YOUR CAR MODEL FROM ABOVE LIST: TRIBER
# ENTER CAR MANUFACTURING YEAR: 2022
# ...
